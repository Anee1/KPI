# %%
import pandas as pd
from KPI import nb_campagnes_marketing, engagement_digital, nb_followers_campagnes, performance_volume_partenariats,taux_transformation_partenariat,nb_partenariats_conclus,nb_partenariats_inities

# %%
donné = pd.read_excel('Imamiah Monney.xlsx', sheet_name=None)
clé = list(donné.keys())
Partenariat_df = donné[clé[0]]
Campagne_df = donné[clé[1]]

# %%
Partenariat_df
# Out:
#   nom_partenaire type_partenaire commercial_responsable  date_premier_contact  \
# 0            NaN             NaN         Imamiah Monney                   NaN
# 1                     Entreprise         Imamiah Monney                   NaN
# 2            NaN          Banque         Imamiah Monney                   NaN
# 3            NaN           autre         Imamiah Monney                   NaN
#
#       statut  origine_contact  objectif_volume  volume_realise
# 0  abandonné      Prospection        5000000.0        150000.0
# 1     Signé          Referral              NaN             NaN
# 2  abandonné      Prospection              NaN             NaN
# 3        NaN              NaN              NaN             NaN

# %%
Campagne_df
# Out:
#    campaign_id  nom_campagne     type_campagne     canal date_lancement  \
# 0          NaN           NaN           terrain  LinkedIn     2026-01-14
# 1          NaN           NaN  institutionnelle     Email     2026-01-15
# 2          NaN           NaN          digitale     Email     2026-01-16
# 3          NaN           NaN  institutionnelle     Email     2026-01-17
# 4          NaN           NaN           terrain     Autre     2026-01-18
# 5          NaN           NaN           terrain       NaN     2026-01-19
#
#     date_fin   budget  impressions  likes  comments  shares  followers_avant  \
# 0 2026-03-05  5000000          520  50000      1000      50              500
# 1 2026-03-06  5000000          520  50000      1000      50              500
# 2 2026-03-07  5000000          520  50000      1000      50              500
# 3 2026-03-08  5000000          520  50000      1000      50              500
# 4 2026-03-09  5000000          520  50000      1000      50              500
# ...

# %%
partenariats_initie = nb_partenariats_inities(Partenariat_df)
Partenariat_conclu = nb_partenariats_conclus(Partenariat_df)
taux_transformation_partenaria =taux_transformation_partenariat(Partenariat_df)
performance_volume_partenariats = performance_volume_partenariats(Partenariat_df)
nb_campagnes_marketing = nb_campagnes_marketing(Campagne_df)
engagement_digital = engagement_digital(Campagne_df)
nb_followers_campagnes = nb_followers_campagnes(Campagne_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 5
#       1 partenariats_initie = nb_partenariats_inities(Partenariat_df)
#       2 Partenariat_conclu = nb_partenariats_conclus(Partenariat_df)
# ----> 5 taux_transformation_partenaria =taux_transformation_partenariat(Partenariat_df)
#       6 performance_volume_partenariats = performance_volume_partenariats(Partenariat_df)
#       7 nb_campagnes_marketing = nb_campagnes_marketing(Campagne_df)
#
# TypeError: 'float' object is not callable

# %%
Partenariat_conclus/partenariats_inities
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 Partenariat_conclus/partenariats_inities
#
# ZeroDivisionError: division by zero

# %%
Partenariat
# Out:
# 0

# %%
Partenariat_conclus
# Out:
# 1

# %%
taux_transformation_partenariat = taux_transformation_partenariat(Partenariat_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 taux_transformation_partenariat = taux_transformation_partenariat(Partenariat_df)
#
# TypeError: 'float' object is not callable

# %%
taux_transformation_partenariat
# Out:
# 0.0

# %%
performance_volume_partenariats
# Out:
# {'objectif_total': 5000000.0,
#  'realise_total': 150000.0,
#  'taux_realisation': 0.03,
#  'detail_par_partenaire': {'        ': {'objectif_volume': 0.0,
#    'volume_realise': 0.0}}}

# %%
nb_campagnes_marketing
# Out:
# 0

# %%
engagement_digital
# Out:
# {'total_impressions': 3120,
#  'total_likes': 300000,
#  'total_comments': 6000,
#  'total_shares': 300,
#  'taux_engagement': np.float64(98.1731),
#  'nb_campagnes': 0,
#  'budget_total': 30000000.0}

# %%
nb_followers_campagnes
# Out:
# {'total_nouveaux_followers': -400,
#  'detail_par_canal': {'Autre': 0, 'Email': 0, 'LinkedIn': -400}}
